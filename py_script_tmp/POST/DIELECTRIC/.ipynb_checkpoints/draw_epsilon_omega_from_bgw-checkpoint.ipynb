# %%
import re
import matplotlib.pyplot as plt
from pymatgen.core.physical_constants import c,h,e
from math import sqrt,pi
import re
import numpy as np

def parse_absorption(filename):
    omega = []
    epsilon2 = []
    epsilon1 =  []
    jdos = []
    with open(filename,'r') as f:
        for line in f:
            if line.split()[0]!='#':
                omega.append(float(line.split()[0]))
                epsilon2.append(float(line.split()[1]))
                epsilon1.append(float(line.split()[2]))
                jdos.append(float(line.split()[3])*500) ####exagerated
    return omega,epsilon2,epsilon1,jdos

def calculate_absorption(filename):
    omega,epsilon2,epsilon1,jdos = parse_absorption(filename)
    constant = 4*pi*e/(h*c)*0.01
    nedos = len(omega)
    norm = np.zeros(nedos)
    k = np.zeros(nedos)
    absorption = np.zeros(nedos)
    for i in range(nedos):
        norm[i] = sqrt(epsilon2[i]**2+epsilon1[i]**2)
        k[i] = sqrt(2)/2*sqrt(norm[i]-epsilon1[i])
        absorption[i] = omega[i]*k[i]*constant
    return absorption

# %%
omega_eh,epsilon2_eh,epsilon1_eh,jdos_eh = parse_absorption('/Users/yao/Google Drive/data/BGW-test/Si/absorption_eh.dat')
omega_noeh,epsilon2_noeh,epsilon1_noeh,jdos_noeh = parse_absorption('/Users/yao/Google Drive/data/BGW-test/Si/absorption_noeh.dat')
absorption_eh = calculate_absorption('/Users/yao/Google Drive/data/BGW-test/Si/absorption_eh.dat')
absorption_noeh = calculate_absorption('/Users/yao/Google Drive/data/BGW-test/Si/absorption_noeh.dat')

# %%
plt.plot(omega_eh,epsilon2_eh,'-',label='epsilon2')
plt.plot(omega_eh,epsilon1_eh, '-',label='epsilon1')
plt.plot(omega_eh,jdos_eh, '-',label='jdos')
plt.xlabel('photon energy(eV)')
plt.legend()
plt.show()

# %%
plt.plot(omega_eh,epsilon2_eh,'-',label='epsilon2_eh')
plt.plot(omega_noeh,epsilon2_noeh, '-',label='epsilon2_noeh')
plt.xlim([0,10])
plt.xlabel('photon energy(eV)')
plt.legend()
plt.show()

# %%
plt.plot(omega_eh,epsilon1_eh,'-',label='epsilon1_eh')
plt.plot(omega_noeh,epsilon1_noeh, '-',label='epsilon1_noeh')
plt.xlim([0,10])
plt.legend()
plt.xlabel('photon energy(eV)')
plt.show()

# %%
plt.plot(omega_eh,jdos_eh,'-',label='jdos_eh')
plt.plot(omega_noeh,jdos_noeh, '-',label='jdos_noeh')
plt.xlim([0,10])
plt.xlabel('photon energy(eV)')
#plt.ylim([0,0.00001])
plt.legend()
plt.show()

# %%
plt.plot(omega_noeh,epsilon2_noeh,'-',label='epsilon2_noeh')
plt.plot(omega_noeh,epsilon1_noeh, '-',label='epsilon1_noeh')
plt.plot(omega_noeh,jdos_noeh, '-',label='jdos_noeh')
plt.legend()
plt.xlabel('photon energy(eV)')
plt.show()

# %%
plt.semilogy(omega_eh, absorption_eh, label='absorption_eh')
plt.semilogy(omega_noeh, absorption_noeh, label='absorption_noeh')
plt.legend(loc = 'best')
plt.ylim([1e2,3e6])
plt.xlim([0,4])
plt.xlabel('photon energy(eV)')
plt.ylabel('absorption(1/cm)')
plt.show()

# %%
plt.plot(omega_eh, absorption_eh, label='absorption_eh')
plt.plot(omega_noeh, absorption_noeh, label='absorption_noeh')
plt.legend(loc = 'best')
plt.xlim([0,10])
plt.xlabel('photon energy(eV)')
plt.ylabel('absorption(1/cm)')
plt.show()
