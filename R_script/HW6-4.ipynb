# %%
data <- read.table("/Users/yao/Desktop/stat201b/HW/HW6/glass.dat")

# %%
x1 <- data$RI
x2 <- data$Ca

# %%
library(MASS)
fhat <- kde2d(x1, x2, n = 100, lims = c(range(x1), range(x2)))
persp(fhat, phi = 30, theta = 20, d = 5, xlab = "RI", ylab="Ca", zlab="kernel density estimate")
# Out:
# plot without title

# %%
c(c(1,3) %o% 10^(3:7))
# Out:
#  [1] 1e+03 3e+03 1e+04 3e+04 1e+05 3e+05 1e+06 3e+06 1e+07 3e+07
