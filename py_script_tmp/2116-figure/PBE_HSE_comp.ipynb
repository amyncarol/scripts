# %%
import matplotlib.pyplot as plt
import pandas as pd

a = pd.read_csv('/Users/yao/Google Drive/data/2116/data/PBE_HSE_comp.csv')
a = a.sort(columns='Eg_bs')
# Out:
# //anaconda/envs/216paper/lib/python3.5/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
plt.plot(range(a.shape[0]), a['Eg_bs'])
plt.plot(range(a.shape[0]), a['Eg_bs_HSE'])
plt.xticks(range(a.shape[0]), a['compound'], rotation='vertical')
plt.show()
a.query('Eg_bs_HSE<2.0')
# Out:
#     Unnamed: 0      compound   Eg_bs  Eg_bs_HSE
# 18        4878  Cs2Ag1In1Br6  0.2659     1.5340
# 10        4210  Rb2Tl1Tl1Br6  0.3615     1.0212
# 6         3835   Rb2Ag1Sb1I6  0.4095     0.9389
# 23        5266  Cs2Tl1Tl1Br6  0.4264     1.0998
# 1         3250  Rb2Li1Tl1Br6  0.5529     1.7251
# 3         3742  Rb2Cu1Bi1Br6  0.6343     1.7233
# 13        4219   Rb2Tl1Sb1I6  0.8740     1.1881
# 22        5171   Cs2In1Tl1I6  0.8885     1.5063
# 12        4215   Rb2Tl1As1I6  0.9148     1.2010
# 9         4209  Rb2Tl1Tl1Cl6  0.9527     1.8606
# 11        4214  Rb2Tl1As1Br6  1.1396     1.5559
# 24        5279   Cs2Tl1Bi1I6  1.3773     1.7904
