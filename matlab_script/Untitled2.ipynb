% %%
m = 10;
r = 6;
A = zeros(m, m);
for i = 1:1:r
    q = rand(m, 1);
    A = A+q*q';
end
rank(A)
size(A)
% Out:
% ans =
%
%      6
%
%
% ans =
%
%     10    10

% %%
[Q, R] = qr(A)
% Out:
% Q =
%
%   Columns 1 through 7
%
%    -0.4255    0.5449    0.1427   -0.0964    0.1135    0.0224    0.4349
%    -0.2926    0.0061    0.1649    0.0425   -0.2653    0.0513    0.4420
%    -0.2181   -0.1977   -0.5433    0.4086   -0.3981    0.3472    0.0240
%    -0.1668   -0.0890    0.2101   -0.2966   -0.1211    0.0789    0.0841
%    -0.3580   -0.3020    0.1469    0.1879   -0.1352    0.1179    0.1754
%    -0.2992    0.5321   -0.4317   -0.1504   -0.2655   -0.2479   -0.3683
%    -0.3379   -0.3071    0.0890    0.2481    0.0137   -0.8088   -0.0795
%    -0.3927   -0.1874    0.3472   -0.3510   -0.1722    0.2740   -0.5687
%    -0.3412    0.1130    0.0246    0.4380    0.6751    0.2556   -0.2550
%    -0.2355   -0.3734   -0.5254   -0.5472    0.4113   -0.0128    0.2161
%
%   Columns 8 through 10
%
%     0.0307    0.5359   -0.0413
%     0.1308   -0.6225   -0.4609
%     0.3070    0.2774   -0.0175
%     0.5349   -0.1740    0.6984
%    -0.7118   -0.0303    0.3913
%    -0.1867   -0.3025    0.1562
% ...
