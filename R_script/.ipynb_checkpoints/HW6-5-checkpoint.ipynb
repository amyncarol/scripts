# %%
load("/Users/yao/Desktop/stat201b/HW/HW6/berkhousing.RData")

data <- berkhousing[with(berkhousing, order(sqft)),]
y <- na.omit(data)$price
x <- na.omit(data)$sqft

print(x)
print(y)
# Out:
#  [1]  477  514  542  600  600  618  653  680  682  720  767  775  792  812  824
# [16]  837  859  867  868  885  892  902  920  922  925  925  931  940  943  948
# [31]  980 1016 1017 1017 1045 1050 1054 1055 1058 1067 1070 1076 1092 1095 1108
# [46] 1116 1118 1132 1137 1160 1176 1179 1180 1196 1210 1213 1247 1250 1261 1265
# [61] 1283 1300 1301 1356 1376 1415 1429 1430 1452
#  [1]  99.888 350.000 309.000 324.900 725.000 315.000 399.000 280.000 399.000
# [10] 595.000 469.500 525.000 425.000 399.000 275.000 489.000 388.000 425.000
# [19] 419.000 410.000 448.000 392.000 499.000 437.000 419.000 459.000 595.000
# [28] 425.000 619.000 299.000 449.000 665.000 445.000 439.000 519.000 370.000
# [37] 440.000 535.000 599.500 519.000 599.000 699.000 539.000 699.000 630.000
# [46] 645.000 575.000 560.000 519.000 545.000 299.000 595.000 575.000 599.000
# [55] 689.000 619.000 635.000 399.000 550.000 629.000 599.000 550.000 649.000
# [64] 649.000 829.000 699.000 679.000 499.000 399.000

# %%
r_knn <- function(smallx, x, y, k){
    dist <- abs(smallx-x)
    df <- data.frame(x, y, dist)
    sorted_df <- df[with(df, order(dist)),]
    print(sorted_df$y[1:k])
    return(sum(sorted_df$y[1:k])/k)
}



jhat_knn <- function(k, x, y){
    index <- 1:length(x)
    cv_x <- sapply(x, get_cv_x, x=x, y=y, simplify=FALSE)
    cv_y <- sapply(x, get_cv_y, x=x, y=y, simplify=FALSE)
    cv_r <- mapply(r_knn, x, cv_x, cv_y, rep(k, length(x)))
    return(sum((y-cv_r)^2))
}

#kseq <- 1:68
#risk <- sapply(kseq, jhat_knn, x=x, y=y)
#plot(kseq, risk, type='l')
#kopt <- kseq[risk==min(risk)]
#print(kopt)
#print(min(risk))
# Out:
# [1] 324.9 725.0 315.0
# [1] 454.9667

# %%
#KNN
library("FNN")
rss <- function(k, x, y){
    model <- knn.reg(train=x, y=y, k=k)
    return(model$PRESS)
}

kseq <- 1:68
rss_seq <- sapply(kseq, rss, x=x, y=y)
kopt <- kseq[rss_seq==min(rss_seq)]

print("the optimal k is:")
print(kopt)
print("the risk estimate is:")
print(min(rss_seq))

plot(kseq, rss_seq, type='l', xlab="k", ylab="residual sum of squares")
# Out:
# [1] "the optimal k is:"
# [1] 29
# [1] "the risk estimate is:"
# [1] 868065.4
# plot without title

# %%
model_opt <- knn.reg(train=x, test=x, y=y, k=kopt)
plot(x, y, xlab='square footage', ylab='price', main="KNN", col='blue')
lines(x, model_opt$pred, type='p', col='red')
legend(list(x = 600,y = 830), legend = c('True', 'Predicted'), col=c('blue', 'red'), lty=1:2)
# Out:
# Error in get.knnx(train, test, k, algorithm): Number of columns must be same!.
# Traceback:
#
# 1. knn.reg(train = x, test = x, y = y, k = kopt)
# 2. get.knnx(train, test, k, algorithm)
# 3. stop("Number of columns must be same!.")

# %%
### kernel regression
w_x <- function(smallx, x, h){
    numer <- dnorm((smallx-x)/h)
    denom <- sum(dnorm((smallx-x)/h))
    return(numer/denom)
}

r_x <- function(smallx, x, y, h){
    return(sum(w_x(smallx, x, h)*y))
}

jhat <- function(h, x, y) {
    crossmat <- outer(x, x, '-')/h
    smallxseq <- x
    numer <- (y-sapply(smallxseq, r_x, x=x, y=y, h=h))^2
    denom <- (1-dnorm(0)/rowSums(dnorm(crossmat)))^2
    return(sum(numer/denom))
}

hseq <- seq(10, max(x)-min(x), length=100)
risk <- sapply(hseq, jhat, x=x, y=y)
plot(hseq, risk)

hopt <- optimize(jhat, lower=10, upper=max(x)-min(x), x=x, y=y)$minimum
print("the optimal bandwidth h is:")
print(hopt)
print("the leave-one-out cv risk estimate is:")
print(jhat(hopt, x, y))

# %%
plot(x, y, xlab='square footage', ylab='price', main="Guassian Kernel", col='blue')
lines(x, sapply(x, r_x, x=x, y=y, h=hopt), type='l', col='red')
legend(list(x = 600,y = 830), legend = c('True', 'Predicted'), col=c('blue', 'red'), lty=1:2)

# %%
rep(0, 69)

# %%
sort(c(2,3,1))

# %%
c(2,3,1)[-2]
