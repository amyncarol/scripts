# %%
s_cand = rnorm(2000, mean = 10, sd = 2)
a = 9
b = 13

# %%
s = s_cand[s_cand > a & s_cand < b]
length(s)
# Out:
# [1] 1281

# %%
hist(s, 30, probability=TRUE)
x <- seq(0, 20, length = 300)
p = pnorm(b, mean = 10, sd = 2)-pnorm(a, mean = 10, sd = 2)
lines(x, dnorm(x, mean = 10, sd = 2)/p)
# Out:
# Plot with title “Histogram of s”
